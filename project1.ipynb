# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student_info.csv")
df
# Out:
#     student_id          name  gender  age  grade_level  math_score  \
# 0           S1     Student_1   Other   17           10          74
# 1           S2     Student_2    Male   17           12          99
# 2           S3     Student_3   Other   17            9          59
# 3           S4     Student_4   Other   17           12          70
# 4           S5     Student_5    Male   15            9          85
# ..         ...           ...     ...  ...          ...         ...
# 995       S996   Student_996  Female   15           10          76
# 996       S997   Student_997  Female   17           12          83
# 997       S998   Student_998   Other   16           10          60
# 998       S999   Student_999   Other   17            9          94
# 999      S1000  Student_1000    Male   17            9          96
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 0               61             90        94.660002         Master's
# ...

# %%
df.head(5)
# Out:
#   student_id       name gender  age  grade_level  math_score  reading_score  \
# 0         S1  Student_1  Other   17           10          74             61
# 1         S2  Student_2   Male   17           12          99             70
# 2         S3  Student_3  Other   17            9          59             60
# 3         S4  Student_4  Other   17           12          70             88
# 4         S5  Student_5   Male   15            9          85             77
#
#    writing_score  attendance_rate parent_education  study_hours  \
# 0             90        94.660002         Master's     4.120192
# 1             91        93.173227       Bachelor's     2.886505
# 2             99        98.631098              PhD     1.909926
# 3             69        96.419620              PhD     1.664740
# 4             94        91.332105              PhD     2.330918
#
#   internet_access       lunch_type extra_activities final_result
# ...

# %%
df.describe()
# Out:
#                age  grade_level   math_score  reading_score  writing_score  \
# count  1000.000000  1000.000000  1000.000000    1000.000000    1000.000000
# mean     15.999000    10.473000    75.165000      74.293000      75.150000
# std       0.817109     1.136029    14.304349      14.312652      14.395094
# min      15.000000     9.000000    50.000000      50.000000      50.000000
# 25%      15.000000     9.000000    63.000000      62.000000      63.000000
# 50%      16.000000    10.000000    75.000000      74.000000      75.000000
# 75%      17.000000    12.000000    88.000000      86.000000      88.000000
# max      17.000000    12.000000    99.000000      99.000000      99.000000
#
#        attendance_rate  study_hours
# count      1000.000000  1000.000000
# mean         89.879179     2.978380
# std           5.725007     1.167780
# min          80.000614     1.015673
# 25%          84.971772     1.955287
# 50%          89.980889     2.962665
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        1000 non-null   object
#  1   name              1000 non-null   object
#  2   gender            1000 non-null   object
#  3   age               1000 non-null   int64
#  4   grade_level       1000 non-null   int64
#  5   math_score        1000 non-null   int64
#  6   reading_score     1000 non-null   int64
#  7   writing_score     1000 non-null   int64
#  8   attendance_rate   1000 non-null   float64
#  9   parent_education  1000 non-null   object
#  10  study_hours       1000 non-null   float64
#  11  internet_access   1000 non-null   object
#  12  lunch_type        1000 non-null   object
#  13  extra_activities  1000 non-null   object
#  14  final_result      1000 non-null   object
# dtypes: float64(2), int64(5), object(8)
# memory usage: 117.3+ KB

# %%
df.isnull().sum()
# Out:
# student_id          0
# name                0
# gender              0
# age                 0
# grade_level         0
# math_score          0
# reading_score       0
# writing_score       0
# attendance_rate     0
# parent_education    0
# study_hours         0
# internet_access     0
# lunch_type          0
# extra_activities    0
# final_result        0
# dtype: int64

# %%
#Replace the name

# %%
n=df.replace(to_replace="Other",value="Female")
n
# Out:
#     student_id          name  gender  age  grade_level  math_score  \
# 0           S1     Student_1  Female   17           10          74
# 1           S2     Student_2    Male   17           12          99
# 2           S3     Student_3  Female   17            9          59
# 3           S4     Student_4  Female   17           12          70
# 4           S5     Student_5    Male   15            9          85
# ..         ...           ...     ...  ...          ...         ...
# 995       S996   Student_996  Female   15           10          76
# 996       S997   Student_997  Female   17           12          83
# 997       S998   Student_998  Female   16           10          60
# 998       S999   Student_999  Female   17            9          94
# 999      S1000  Student_1000    Male   17            9          96
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 0               61             90        94.660002         Master's
# ...

# %%
#Gender Distridution

# %%
plt.figure(figsize=(4,3))
ax=sns.countplot(data=n, x="gender")
ax.bar_label(ax.containers[0])
plt.title('Gender Distribution')
plt.show()

# %%
#from the above chart we have analyzed that:
#the number of females in the data is more than the number of males

# %%
gb=df.groupby('parent_education').agg({"math_score":'mean',"reading_score":'mean',"writing_score":'mean'})
gb
# Out:
#                   math_score  reading_score  writing_score
# parent_education
# Bachelor's         75.627737      74.328467      75.218978
# High School        75.404082      73.453061      76.461224
# Master's           73.242291      73.651982      75.070485
# PhD                76.153543      75.637795      73.881890

# %%
plt.figure(figsize=(4,3))
sns.heatmap(gb,annot=True)
plt.title('Relation Between Parent Education')
plt.show()

# %%
#from the above chart we have concluded that the education of parents have a good impact on their children

# %%
gb1=df.groupby('internet_access').agg({"math_score":'mean',"reading_score":'mean',"writing_score":'mean'})
gb1
# Out:
#                  math_score  reading_score  writing_score
# internet_access
# No                    75.08         74.344         74.914
# Yes                   75.25         74.242         75.386

# %%
plt.figure(figsize=(4,3))
sns.heatmap(gb1,annot=True)
plt.title('Relation Between Internet Access')
plt.show()

# %%
#from the above chart we have analyze that internet access have no impact on students marks

# %%
sns.boxplot(data=n,x="math_score")
plt.title('Outliers of Math Score')
plt.show()

# %%
sns.boxplot(data=n,x="reading_score")
plt.title('Outliers of Reading Score')
plt.show()

# %%
sns.boxplot(data=n,x="writing_score")
plt.title('Outliers of Writing Score')
plt.show()

# %%
sns.boxplot(data=n,x="study_hours")
plt.title('Outliers of Study Hours')
plt.show()

# %%
nd=df.replace(to_replace = ['Free or reduced', 'Standard'], value = ['group A','group B'])
nd
# Out:
#     student_id          name  gender  age  grade_level  math_score  \
# 0           S1     Student_1   Other   17           10          74
# 1           S2     Student_2    Male   17           12          99
# 2           S3     Student_3   Other   17            9          59
# 3           S4     Student_4   Other   17           12          70
# 4           S5     Student_5    Male   15            9          85
# ..         ...           ...     ...  ...          ...         ...
# 995       S996   Student_996  Female   15           10          76
# 996       S997   Student_997  Female   17           12          83
# 997       S998   Student_998   Other   16           10          60
# 998       S999   Student_999   Other   17            9          94
# 999      S1000  Student_1000    Male   17            9          96
#
#      reading_score  writing_score  attendance_rate parent_education  \
# 0               61             90        94.660002         Master's
# ...

# %%
print(nd['lunch_type'].unique())
# Out:
# ['group A' 'group B']

# %%
groupA=nd.loc[(nd['lunch_type'] == "group A")].count()
groupB=nd.loc[(nd['lunch_type'] == "group B")].count()
l = ["group A", "group B"]
ml = [groupA['lunch_type'],groupB['lunch_type']] 
print(ml)
plt.title('Distribution of lunch type')
plt.pie(ml, labels=l, autopct="%1.2f%%")
plt.show()
# Out:
# [np.int64(498), np.int64(502)]

# %%
aq=sns.countplot(data=nd, x = "lunch_type")
aq.bar_label(aq.containers[0])
plt.title('Distribution of Lunch Type')
plt.show()
